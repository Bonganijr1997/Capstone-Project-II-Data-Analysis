# %% [markdown]
# Exploratory data analysis (EDA) is a crucial component of data science which allows you to understand the basics of what your data looks like and what kinds of questions might be answered. For this task, we are going to clean, sanitise and explore our data. Using the movies dataset, complete the steps outlined in this notebook by writing code in the cells.

# %%
# Import libraries

import numpy as np
import pandas as pd
import seaborn as sns
import ast, json

from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# Load the automobile dataset
df = pd.read_csv('automobile.txt', delimiter=';')

# Display basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                   --------------  -----
# ...

# %% [markdown]
# ### Data Cleansing
# #### Clean the data

# %%
# Identify and handle missing values (if any)
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %% [markdown]
# #### Remove any duplicate rows

# %%
# Remove duplicate rows (if any)
df.drop_duplicates(inplace=True)
# Code here

# %% [markdown]
# #### Remove rows with missing data
#
# Some movies in the database have zero budget or zero revenue which implies that their values have not been recorded or some information is missing. Discard such entries from the dataframe.

# %%
# Code here
# Convert data types as needed (e.g., convert 'price' to numeric)
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %% [markdown]
# #### Change data types
# To manipulate the columns easily, it is important that we make use of the python objects. Change the release date column into `DateTime` format and extract the year from the date. This will help us in analysing yearly data.

# %%
# Convert data types as needed (e.g., convert 'price' to numeric)
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %% [markdown]
# Change budget and revenue columns to a integer data type using numpy’s `int64` method.

# %%
# Code here

# %% [markdown]
# On checking the dataset, we see that `genres`, `production_countries`, `spoken_languages` are in the JSON format which will make it difficult to manipulate the dataframe. The `parse_col_json function` flattens these columns into a format that can be easily interpreted.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a histogram to visualize the distribution of car prices
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=20, kde=True, color='blue')
plt.title('Distribution of Car Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# We create a histogram to understand the distribution of car prices.
# The histogram helps us identify the price range in which most cars fall

# %%
# Create a scatter plot to explore the relationship between horsepower and car prices
plt.figure(figsize=(10, 6))
plt.scatter(df['horsepower'], df['price'], alpha=0.5, color='green')
plt.title('Horsepower vs. Car Price')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.grid(True)
plt.show()

#Data Story:
#We create a scatter plot to analyze how horsepower relates to car prices.
#This plot helps us identify any correlation between these two variables.

# %%
# Create a bar plot to visualize the distribution of car body styles
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='body-style', palette='magma')
plt.title('Distribution of Car Body Styles')
plt.xlabel('Body Style')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# We create a bar plot to show the distribution of car body styles.
# This plot provides insights into the popularity of different body styles.

# %% [markdown]
# we conducted an exploratory data analysis (EDA) on the "automobile.txt" dataset. We cleaned the data, handled missing values, removed duplicates, and converted data types as needed. Additionally, we explored the data by answering questions and creating visualizations to gain insights into car prices, horsepower, and body styles.
